# %%
import pandas as pd

# %%
df_good = pd.read_csv("training_good.csv")
df_bad = pd.read_csv("training_bad.csv")

# %%
df = pd.concat([df_good,df_bad])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = pd.concat(df_good,df_bad)
#
# TypeError: concat() takes 1 positional argument but 2 were given
